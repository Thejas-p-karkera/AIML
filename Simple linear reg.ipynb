# %% [markdown]
# # Simple linear Regression(Using Library function)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Sample data
x = np.array([5, 7, 12, 16, 20]).reshape(-1, 1)  # Independent variable
y = np.array([40, 120, 180, 210, 240])          # Dependent variable

# Create and train the model
model = LinearRegression()
model.fit(x, y)

# Predict values
y_pred = model.predict(x)

# Print model parameters
print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)

# Calculate error metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mse)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)

# Plot actual vs predicted
plt.scatter(x, y, color='blue', label='Actual')
plt.plot(x, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Slope (Coefficient): 12.20779220779221
# Intercept: 11.506493506493484
# Mean Squared Error (MSE): 465.87012987012986
# Mean Absolute Error (MAE): 19.283116883116882
# Root Mean Squared Error (RMSE): 21.58402487651758

# %% [markdown]
# # simple linear function without Library function

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data
x = np.array([5, 7, 12, 16, 20])
y = np.array([40, 120, 180, 210, 240])

# Step 1: Calculate slope (m) and intercept (b) manually
#n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

# Calculate slope (m)
numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean) ** 2)
slope = numerator / denominator

# Calculate intercept (b)
intercept = y_mean - slope * x_mean

print("Slope (Coefficient):", slope)
print("Intercept:", intercept)

# Step 2: Predict values
y_pred = slope * x + intercept

# Step 3: Calculate error metrics manually
mse = np.mean((y - y_pred) ** 2)
mae = np.mean(np.abs(y - y_pred))
rmse = np.sqrt(mse)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)

# Step 4: Plot actual vs predicted
plt.scatter(x, y, color='blue', label='Actual')
plt.plot(x, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Manual Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Slope (Coefficient): 12.207792207792208
# Intercept: 11.506493506493513
# Mean Squared Error (MSE): 465.87012987013014
# Mean Absolute Error (MAE): 19.283116883116886
# Root Mean Squared Error (RMSE): 21.58402487651759

# %% [markdown]
# # Simple Linear Regression(using Matrix method)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data
x = np.array([5, 7, 12, 16, 20])
y = np.array([40, 120, 180, 210, 240])

# Step 1: Prepare the design matrix X and target vector Y
X = np.vstack([np.ones(len(x)), x]).T  # Add intercept term
Y = y.reshape(-1, 1)

# Step 2: Compute coefficients using the Normal Equation: θ = (XᵀX)⁻¹XᵀY
theta = np.linalg.inv(X.T @ X) @ X.T @ Y
intercept, slope = theta.flatten()

print("Slope (Coefficient):", slope)
print("Intercept:", intercept)

# Step 3: Predict values
y_pred = X @ theta
y_pred = y_pred.flatten()

# Step 4: Calculate error metrics
mse = np.mean((y - y_pred) ** 2)
mae = np.mean(np.abs(y - y_pred))
rmse = np.sqrt(mse)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)

# Step 5: Plot actual vs predicted
plt.scatter(x, y, color='blue', label='Actual')
plt.plot(x, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression (Matrix Method)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Slope (Coefficient): 12.207792207792213
# Intercept: 11.506493506493598
# Mean Squared Error (MSE): 465.8701298701296
# Mean Absolute Error (MAE): 19.283116883116847
# Root Mean Squared Error (RMSE): 21.584024876517578
